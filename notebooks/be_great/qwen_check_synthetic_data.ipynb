# %%
# %pip install sdv pandas numpy plt seaborn
# Out:
# Requirement already satisfied: sdv in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (1.35.1)
# Requirement already satisfied: pandas in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (2.4.4)
# Requirement already satisfied: plt in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (0.2.0)
# Requirement already satisfied: seaborn in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from sdv) (1.42.79)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from sdv) (1.42.79)
# Requirement already satisfied: cloudpickle>=2.1.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from sdv) (3.1.2)
# Requirement already satisfied: graphviz>=0.13.2 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from sdv) (0.21)
# Requirement already satisfied: tqdm>=4.29 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from sdv) (4.67.3)
# Requirement already satisfied: copulas>=0.12.1 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from sdv) (0.14.1)
# Requirement already satisfied: ctgan>=0.11.1 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from sdv) (0.12.1)
# Requirement already satisfied: deepecho>=0.7.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from sdv) (0.8.1)
# Requirement already satisfied: rdt>=1.18.2 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from sdv) (1.20.0)
# Requirement already satisfied: sdmetrics>=0.28.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from sdv) (0.28.0)
# Requirement already satisfied: platformdirs>=4.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from sdv) (4.9.4)
# Requirement already satisfied: pyyaml>=6.0.1 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from sdv) (6.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from pandas) (2025.3)
# Requirement already satisfied: matplotlib in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from plt) (3.10.8)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from boto3<2.0.0,>=1.28->sdv) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from boto3<2.0.0,>=1.28->sdv) (0.16.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from botocore<2.0.0,>=1.31->sdv) (2.6.3)
# Requirement already satisfied: plotly>=5.10.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from copulas>=0.12.1->sdv) (6.6.0)
# Requirement already satisfied: scipy>=1.12.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from copulas>=0.12.1->sdv) (1.17.1)
# Requirement already satisfied: torch>=2.3.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from ctgan>=0.11.1->sdv) (2.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from matplotlib->plt) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from matplotlib->plt) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from matplotlib->plt) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from matplotlib->plt) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from matplotlib->plt) (26.0)
# Requirement already satisfied: pillow>=8 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from matplotlib->plt) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from matplotlib->plt) (3.3.2)
# Requirement already satisfied: six>=1.5 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: scikit-learn>=1.3.1 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from rdt>=1.18.2->sdv) (1.8.0)
# Requirement already satisfied: Faker!=37.11.0,>=17 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from rdt>=1.18.2->sdv) (40.12.0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (2.18.1)
# Requirement already satisfied: joblib>=1.3.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from scikit-learn>=1.3.1->rdt>=1.18.2->sdv) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from scikit-learn>=1.3.1->rdt>=1.18.2->sdv) (3.6.0)
# Requirement already satisfied: filelock in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (4.15.0)
# Requirement already satisfied: setuptools<82 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.6.1)
# Requirement already satisfied: jinja2 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (2026.2.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.3.0->ctgan>=0.11.1->sdv) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from torch>=2.3.0->ctgan>=0.11.1->sdv) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.3.0->ctgan>=0.11.1->sdv) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.3.0->ctgan>=0.11.1->sdv) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.3.0->ctgan>=0.11.1->sdv) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.3.0->ctgan>=0.11.1->sdv) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.3.0->ctgan>=0.11.1->sdv) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.3.0->ctgan>=0.11.1->sdv) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.3.0->ctgan>=0.11.1->sdv) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.3.0->ctgan>=0.11.1->sdv) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.3.0->ctgan>=0.11.1->sdv) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.3.0->ctgan>=0.11.1->sdv) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.3.0->ctgan>=0.11.1->sdv) (13.0.85)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch>=2.3.0->ctgan>=0.11.1->sdv) (1.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.3.0->ctgan>=0.11.1->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/aperez/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages (from jinja2->torch>=2.3.0->ctgan>=0.11.1->sdv) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from sdv.metadata import SingleTableMetadata
from scipy.stats import ks_2samp, chi2_contingency

warnings.filterwarnings('ignore')
sns.set_theme(style="whitegrid")

# Cargar el dataset de ejemplo oficial
# Este dataset está pre-limpiado para pruebas de síntesis
url_real_data = "../../datasources/bank_full_dataset/bank-full.csv"
df_real = pd.read_csv(url_real_data, sep=';')
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(df_real)

print("Columnas del dataset:", df_real.columns.tolist())
df_real.head()

num_cols = df_real.select_dtypes(include=[np.number]).columns
print("Columnas numericas:", num_cols)
cat_cols = df_real.select_dtypes(exclude=[np.number]).columns
print("Columnas categoricas:", cat_cols)

url_synth_data = "qwen_synth_out.csv"
df_synth = pd.read_csv(url_synth_data, sep=',', index_col=0)
# Out:
# Columnas del dataset: ['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'y']
# Columnas numericas: Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')
# Columnas categoricas: Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
def reporte_calidad(real, synth):
    print("\n" + "="*40)
    print("   REPORTE DE FIDELIDAD ESTADÍSTICA")
    print("="*40 + "\n")
      
    # Test de Proporciones para Categóricas (Diferencia Media)
    cat_cols = df_real.select_dtypes(exclude=[np.number]).columns
    for col in cat_cols:
        f_real = real[col].value_counts(normalize=True).sort_index()
        f_synth = synth[col].value_counts(normalize=True).sort_index()
        
        diff = (f_real - f_synth).abs().mean()
        status = "✅ FIEL" if diff < 0.05 else "❌ DESVIADO"
        print(f"Prop. Diff [{col:10}]: {diff:.4f} {status}")

reporte_calidad(df_real, df_synth)
# Out:
# ========================================
#    REPORTE DE FIDELIDAD ESTADÍSTICA
# ========================================
#
# Prop. Diff [job       ]: 0.0252 ✅ FIEL
# Prop. Diff [marital   ]: 0.0374 ✅ FIEL
# Prop. Diff [education ]: 0.0408 ✅ FIEL
# Prop. Diff [default   ]: 0.0170 ✅ FIEL
# Prop. Diff [housing   ]: 0.0378 ✅ FIEL
# Prop. Diff [loan      ]: 0.1052 ❌ DESVIADO
# Prop. Diff [contact   ]: 0.1040 ❌ DESVIADO
# Prop. Diff [month     ]: 0.0229 ✅ FIEL
# Prop. Diff [poutcome  ]: 0.0508 ❌ DESVIADO
# Prop. Diff [y         ]: 0.0670 ❌ DESVIADO

# %%
def plot_ks_visual(real, synth, col):
    plt.figure(figsize=(8, 4))
    sns.ecdfplot(real[col], label='Real', color='blue', linewidth=2)
    sns.ecdfplot(synth[col], label='Sintético', color='red', linestyle='dashed', linewidth=2)
    plt.title(f"Comparativa de Distribución Acumulada (ECDF) - {col}")
    plt.legend()
    plt.grid(alpha=0.3)
    plt.show()

# Visualizar la columna más crítica (usualmente balance o age)
for col_critica in num_cols:
    plot_ks_visual(df_real, df_synth, col_critica)

plot_ks_visual(df_real, df_synth, 'age')
plot_ks_visual(df_real, df_synth, 'day')

# %%
from scipy.stats import ks_2samp
import matplotlib.pyplot as plt

for col in ['age', 'day']:
    d_stat, p_val = ks_2samp(df_real[col], df_synth[col])
    print(f"--- Columna: {col} ---")
    print(f"Distancia K-S (D): {d_stat:.4f}")
    print(f"P-valor: {p_val:.4f}")
    
    # Visualización de la diferencia acumulada
    plt.figure(figsize=(8, 4))
    plt.hist(df_real[col], bins=50, alpha=0.5, label='Real', density=True)
    plt.hist(df_synth[col], bins=50, alpha=0.5, label='Sintético', density=True)
    plt.title(f"Histograma Comparativo: {col}")
    plt.legend()
    plt.show()
# Out:
# --- Columna: age ---
# Distancia K-S (D): 0.0450
# P-valor: 0.0369
# --- Columna: day ---
# Distancia K-S (D): 0.1250
# P-valor: 0.0000

# %%
from sdv.evaluation.single_table import evaluate_quality
from sdv.evaluation.single_table import get_column_plot

# --- Evaluación de Calidad Global ---
# Compara el dataframe original (df) con el sintético (synthetic_data)
quality_report = evaluate_quality(
    real_data=df_real,
    synthetic_data=df_synth,
    metadata=metadata
)

# Obtenemos las puntuaciones detalladas
print(f"\nScore de Calidad Global: {quality_report.get_score():.2%}")
quality_report.get_details('Column Shapes') # Fidelidad de las distribuciones
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 17/17 [00:00<00:00, 197.66it/s]|
# Column Shapes Score: 90.51%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 136/136 [00:01<00:00, 135.84it/s]|
# Column Pair Trends Score: 79.56%
#
# Overall Score (Average): 85.03%
#
#
# Score de Calidad Global: 85.03%
#        Column        Metric     Score
# 0         age  KSComplement  0.954996
# 1         job  TVComplement  0.857454
# 2     marital  TVComplement  0.943933
# 3   education  TVComplement  0.918392
# 4     default  TVComplement  0.982973
# 5     balance  KSComplement  0.876547
# 6     housing  TVComplement  0.962162
# 7        loan  TVComplement  0.894774
# 8     contact  TVComplement  0.843983
# 9         day  KSComplement  0.875014
# 10      month  TVComplement  0.871793
# 11   duration  KSComplement  0.901481
# 12   campaign  KSComplement  0.874639
# 13      pdays  KSComplement  0.898367
# 14   previous  KSComplement  0.898367
# 15   poutcome  TVComplement  0.898478
# 16          y  TVComplement  0.933015

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calcular matrices de correlación usando Spearman (ideal para distribuciones no normales)
corr_real = df_real[num_cols].corr(method='spearman')
corr_sintetica = df_synth[num_cols].corr(method='spearman')

# Calcular la diferencia absoluta entre ambas matrices
matriz_diferencia = np.abs(corr_real - corr_sintetica)

# Configurar el estilo visual para presentación
sns.set_context("talk")
plt.figure(figsize=(10, 8))

# Graficamos la matriz de error
sns.heatmap(
    matriz_diferencia, 
    annot=True, 
    cmap="Oranges", 
    fmt=".2f", 
    linewidths=.5,
    cbar_kws={'label': 'Error Absoluto de Correlación'}
)

plt.title("Matriz de Error: Diferencia de Correlación (Real vs Sintético)", fontsize=16, fontweight='bold', pad=15)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Métrica de resumen: Error Medio Absoluto (MAE) de las correlaciones
# Tomamos solo el triángulo superior para no duplicar los cálculos (la matriz es simétrica)
indices_triu = np.triu_indices_from(matriz_diferencia, k=1)
mae_corr = matriz_diferencia.values[indices_triu].mean()

print("-" * 50)
print(f"Resumen de Precisión de Relaciones:")
print(f"Error Medio Absoluto de Correlación (MAE): {mae_corr:.4f}")
print("-" * 50)

if mae_corr <= 0.05:
    print("El modelo respeta las relaciones de manera óptima.")
elif mae_corr <= 0.10:
    print("Resultado aceptable. Hay ligeras desviaciones en algunas relaciones.")
else:
    print("❌ El error es alto. Considera revisar los hiperparámetros o la distribución por defecto.")
# Out:
# --------------------------------------------------
# Resumen de Precisión de Relaciones:
# Error Medio Absoluto de Correlación (MAE): 0.0518
# --------------------------------------------------
# Resultado aceptable. Hay ligeras desviaciones en algunas relaciones.

# %%
# Evaluamos la calidad de los datos con TSTR

import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.preprocessing import LabelEncoder

# 1. Copias de seguridad para no alterar los DataFrames originales
df_real_ml = df_real.copy()
df_syn_ml = df_synth.copy()

# 2. Preprocesamiento: Encodear variables categóricas (necesario para Random Forest)
label_encoders = {}
categorical_cols = df_real_ml.select_dtypes(include=['object']).columns

print(f"check: {df_real_ml.select_dtypes(include=['object']).columns}")

print(f"check: {df_syn_ml.select_dtypes(include=['object']).columns}")

for col in categorical_cols:
    le = LabelEncoder()
    # Entrenamos el encoder únicamente con los datos reales
    df_real_ml[col] = le.fit_transform(df_real_ml[col].astype(str))
    # Transformamos los datos sintéticos con el mismo criterio
    df_syn_ml[col] = le.transform(df_syn_ml[col].astype(str))

# 3. Separar Variables Predictoras (X) y Objetivo (y)
X_real = df_real_ml.drop(columns=['y'])
y_real = df_real_ml['y']

X_syn = df_syn_ml.drop(columns=['y'])
y_syn = df_syn_ml['y']

# 4. Dividir el dataset REAL en entrenamiento y prueba
# Reservamos un 20% de datos reales puros para la evaluación final de ambos modelos
X_real_train, X_real_test, y_real_train, y_real_test = train_test_split(
    X_real, y_real, test_size=0.2, random_state=42, stratify=y_real
)

# --- MODELO A: Entrenado con Datos Reales ---
model_real = RandomForestClassifier(random_state=42, n_estimators=100)
model_real.fit(X_real_train, y_real_train)

y_pred_real = model_real.predict(X_real_test)
y_proba_real = model_real.predict_proba(X_real_test)[:, 1]

# --- MODELO B: Entrenado con Datos Sintéticos ---
model_syn = RandomForestClassifier(random_state=42, n_estimators=100)
# Entrenamos con TODOS los datos sintéticos generados
model_syn.fit(X_syn, y_syn)

y_pred_syn = model_syn.predict(X_real_test)
y_proba_syn = model_syn.predict_proba(X_real_test)[:, 1]

# 5. Reporte Comparativo de Resultados
print("=" * 60)
print("📊 RESULTADOS DE MACHINE LEARNING EFFICACY")
print("=" * 60)

roc_real = roc_auc_score(y_real_test, y_proba_real)
roc_syn = roc_auc_score(y_real_test, y_proba_syn)

print(f"🏆 ROC AUC [Modelo entrenado con Datos Reales]:    {roc_real:.4f}")
print(f"🎭 ROC AUC [Modelo entrenado con Datos Sintéticos]: {roc_syn:.4f}")
print("-" * 60)

# Calculamos la retención de la capacidad predictiva
retencion_eficacia = (roc_syn / roc_real) * 100
print(f"La calidad de tus datos sintéticos retiene el {retencion_eficacia:.2f}% de la capacidad predictiva.")
print("=" * 60)

print("\n📋 Detalle de Clasificación (Modelo Sintético evaluando Datos Reales):")
print(classification_report(y_real_test, y_pred_syn))
# Out:
# check: Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')
# check: Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages/sklearn/utils/_encode.py:229, in _encode(values, uniques, check_unknown)
#     228 try:
# --> 229     return _map_to_integer(values, uniques)
#     230 except KeyError as e:
#
# File ~/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages/sklearn/utils/_encode.py:168, in _map_to_integer(values, uniques)
#     167 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 168 return xp.asarray([table[v] for v in values], device=device(values))
#
# File ~/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages/sklearn/utils/_encode.py:161, in _nandict.__missing__(self, key)
#     160     return self.nan_value
# --> 161 raise KeyError(key)
#
# KeyError: 'admin. __index_level_0__ is 22158'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 26
#      22     le = LabelEncoder()
#      23     # Entrenamos el encoder únicamente con los datos reales
#      24     df_real_ml[col] = le.fit_transform(df_real_ml[col].astype(str))
#      25     # Transformamos los datos sintéticos con el mismo criterio
# ---> 26     df_syn_ml[col] = le.transform(df_syn_ml[col].astype(str))
#      27
#      28 # 3. Separar Variables Predictoras (X) y Objetivo (y)
#      29 X_real = df_real_ml.drop(columns=['y'])
#
# File ~/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:144, in LabelEncoder.transform(self, y)
#     141 if _num_samples(y) == 0:
#     142     return xp.asarray([])
# --> 144 return _encode(y, uniques=self.classes_)
#
# File ~/gl-work/synthetic-data-learning/.venv/lib/python3.12/site-packages/sklearn/utils/_encode.py:231, in _encode(values, uniques, check_unknown)
#     229         return _map_to_integer(values, uniques)
#     230     except KeyError as e:
# --> 231         raise ValueError(f"y contains previously unseen labels: {e}")
#     232 else:
#     233     if check_unknown:
#
# ValueError: y contains previously unseen labels: 'admin. __index_level_0__ is 22158'

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import pairwise_distances
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Preprocesamiento homogéneo para medir distancias reales
# Para que la distancia sea justa, normalizamos los números y encodeamos las categorías
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('cat', OneHotEncoder(sparse_output=False, handle_unknown='ignore'), cat_cols)
    ]
)

# Tomamos una muestra para agilizar el cálculo de distancias (las matrices grandes saturan la RAM)
n_muestras = min(20000, len(df_real), len(df_synth))
df_real_sample = df_real.sample(n=n_muestras, random_state=42)
df_syn_sample = df_synth.sample(n=n_muestras, random_state=42)

# Ajustamos el preprocesador solo con los datos reales y transformamos ambos
X_real_transformed = preprocessor.fit_transform(df_real_sample)
X_syn_transformed = preprocessor.transform(df_syn_sample)

# Calcular la matriz de distancias euclidianas entre sintéticos y reales
# Cada fila representará un registro sintético y cada columna un registro real
distancias = pairwise_distances(X_syn_transformed, X_real_transformed, metric='euclidean')

# Encontrar la distancia al registro real más cercano para cada registro sintético
# Esto representa la "Similitud Máxima"
distancia_minima_por_registro = np.min(distancias, axis=1)

# Visualización de la distribución de distancias mínimas
plt.figure(figsize=(10, 6))
sns.set_context("talk")
sns.histplot(distancia_minima_por_registro, bins=30, kde=True, color="purple")

plt.axvline(x=0.1, color='red', linestyle='--', label='Zona de riesgo de copia (< 0.1)')
plt.title("Distribución de la Distancia al Registro Real más Cercano", fontsize=16, fontweight='bold', pad=15)
plt.xlabel("Distancia Mínima (A menor distancia, mayor similitud)")
plt.ylabel("Frecuencia")
plt.legend()
plt.tight_layout()
plt.show()

# Reporte de Resultados
proporcion_identicos = np.mean(distancia_minima_por_registro < 0.1) * 100

print("=" * 60)
print("🛡️ REPORTE DE SIMILITUD MÁXIMA Y PRIVACIDAD")
print("=" * 60)
print(f"Distancia mínima promedio general: {distancia_minima_por_registro.mean():.4f}")
print(f"Distancia mínima absoluta encontrada: {distancia_minima_por_registro.min():.4f}")
print(f"Porcentaje de datos sintéticos casi idénticos a los reales: {proporcion_identicos:.4f}%")
print("=" * 60)

if proporcion_identicos > 1.0:
    print("❌ Alerta: El modelo está memorizando demasiados datos reales. Reduce las épocas o simplifica el modelo.")
elif distancia_minima_por_registro.mean() > 5.0:
    print("⚠️ Alerta: Los datos sintéticos están demasiado lejos de los reales. El modelo no está capturando bien la densidad.")
else:
    print("✅ ¡Excelente balance! El modelo genera datos nuevos sin copiar idénticamente los registros reales.")
# Out:
# ============================================================
# 🛡️ REPORTE DE SIMILITUD MÁXIMA Y PRIVACIDAD
# ============================================================
# Distancia mínima promedio general: 1.5928
# Distancia mínima absoluta encontrada: 0.1994
# Porcentaje de datos sintéticos casi idénticos a los reales: 0.0000%
# ============================================================
# ✅ ¡Excelente balance! El modelo genera datos nuevos sin copiar idénticamente los registros reales.

# %%
import pandas as pd
from sdmetrics.single_column import KSComplement, CSTest

# Asumimos que ya tienes tus datos cargados en dos DataFrames: 'df_real' y 'df_synth'
print("--- Resultados de la Prueba KS (KSComplement) para numéricas ---")
for col in num_cols:
    # KSComplement evalúa la similitud de distribuciones continuas
    score_ks = KSComplement.compute(
        real_data=df_real[col],
        synthetic_data=df_synth[col]
    )
    print(f"Columna '{col}': {score_ks:.4f}")

print("\n--- Resultados de la Prueba Chi-cuadrado (CSTest) para categóricas ---")
for col in cat_cols:
    # CSTest evalúa la similitud de frecuencias en categorías
    score_cs = CSTest.compute(
        real_data=df_real[col],
        synthetic_data=df_synth[col]
    )
    print(f"Columna '{col}': {score_cs:.4f}")
# Out:
# --- Resultados de la Prueba KS (KSComplement) para numéricas ---
# Columna 'age': 0.9550
# Columna 'balance': 0.8765
# Columna 'day': 0.8750
# Columna 'duration': 0.9015
# Columna 'campaign': 0.8746
# Columna 'pdays': 0.8984
# Columna 'previous': 0.8984
#
# --- Resultados de la Prueba Chi-cuadrado (CSTest) para categóricas ---
# Columna 'job': 0.0000
# Columna 'marital': 0.9921
# Columna 'education': 0.9973
# Columna 'default': 0.8982
# Columna 'housing': 0.9393
# Columna 'loan': 0.7742
# Columna 'contact': 0.9364
# Columna 'month': 1.0000
# Columna 'poutcome': 0.9948
# Columna 'y': 0.8349
